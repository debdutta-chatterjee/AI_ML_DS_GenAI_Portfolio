# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_similarity([[3,2]],[[3,2]])
# Out:
# array([[1.]])

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(
    model_name = 'sentence-transformers/all-MiniLM-L6-v2',
    
)
embeddings
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\Debdutta Chatterjee\Work\Project\Python\AI_ML_DS_GenAI_Portfolio\.venv\Lib\site-packages\transformers\activations_tf.py:22
#      21 try:
# ---> 22     import tf_keras as keras
#      23 except (ModuleNotFoundError, ImportError):
#
# File c:\Users\Debdutta Chatterjee\Work\Project\Python\AI_ML_DS_GenAI_Portfolio\.venv\Lib\site-packages\tf_keras\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from tf_keras import __internal__
#       4 from tf_keras import activations
#
# File c:\Users\Debdutta Chatterjee\Work\Project\Python\AI_ML_DS_GenAI_Portfolio\.venv\Lib\site-packages\tf_keras\__internal__\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from tf_keras.__internal__ import backend
#       4 from tf_keras.__internal__ import layers
#
# ...

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings = GoogleGenerativeAIEmbeddings(
    model = 'models/text-embedding-004',
   google_api_key ='AIzaSyCtTc-rIeCTfJsfIMHFqnSIjhPbSJpy5Yc'
)

embeddings


text="Hello, I am learning about embeddings!"
em = embeddings.embed_query(text)

# %%
len(em)
# Out:
# 768

# %%
documents = [
    "LangChain is a framework for developing applications powered by language models",
    "Python is a high-level programming language",
    "Machine learning is a subset of artificial intelligence",
    "Embeddings convert text into numerical vectors",
    "The weather today is sunny and warm"
]
query="What is Langchain?"

# %%
def semantic_search(query,documents,embeddings_models,top_k=3):
    q = embeddings_models.embed_query(query)
    d = embeddings_models.embed_documents(documents)

    sim = []
    for i,doc in enumerate(d):
        similarity = cosine_similarity([q],[doc])
        sim.append((similarity,documents[i]))

    sim.sort(reverse=True) 
    return sim[:top_k]

# %%
results=semantic_search(query,documents,embeddings)
results
# Out:
# [(array([[0.86681791]]),
#   'LangChain is a framework for developing applications powered by language models'),
#  (array([[0.69832273]]), 'Python is a high-level programming language'),
#  (array([[0.6693624]]), 'Embeddings convert text into numerical vectors')]
