# %%
import spacy
nlp = spacy.load('en_core_web_sm')
doc = nlp(' I will google about facebook')
doc.text
# Out:
# ' I will google about facebook'

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      -- ------------------------------------- 0.8/12.8 MB 3.4 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.6/12.8 MB 3.4 MB/s eta 0:00:04
#      ----- ---------------------------------- 1.8/12.8 MB 3.2 MB/s eta 0:00:04
#      ------- -------------------------------- 2.4/12.8 MB 2.5 MB/s eta 0:00:05
#      -------- ------------------------------- 2.6/12.8 MB 2.4 MB/s eta 0:00:05
#      --------- ------------------------------ 3.1/12.8 MB 2.5 MB/s eta 0:00:04
#      ---------- ----------------------------- 3.4/12.8 MB 2.4 MB/s eta 0:00:04
#      ------------ --------------------------- 3.9/12.8 MB 2.3 MB/s eta 0:00:04
#      ------------- -------------------------- 4.5/12.8 MB 2.3 MB/s eta 0:00:04
#      --------------- ------------------------ 5.0/12.8 MB 2.4 MB/s eta 0:00:04
#      ------------------ --------------------- 5.8/12.8 MB 2.4 MB/s eta 0:00:03
#      ------------------- -------------------- 6.3/12.8 MB 2.4 MB/s eta 0:00:03
#      ---------------------- ----------------- 7.1/12.8 MB 2.5 MB/s eta 0:00:03
#      ------------------------ --------------- 7.9/12.8 MB 2.6 MB/s eta 0:00:02
#      -------------------------- ------------- 8.4/12.8 MB 2.6 MB/s eta 0:00:02
#      ---------------------------- ----------- 9.2/12.8 MB 2.7 MB/s eta 0:00:02
#      ------------------------------- -------- 10.2/12.8 MB 2.8 MB/s eta 0:00:01
#      --------------------------------- ------ 10.7/12.8 MB 2.8 MB/s eta 0:00:01
#      ------------------------------------ --- 11.5/12.8 MB 2.8 MB/s eta 0:00:01
#      ------------------------------------ --- 11.8/12.8 MB 2.8 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/12.8 MB 2.7 MB/s eta 0:00:01
#      -------------------------------------- - 12.3/12.8 MB 2.7 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 2.6 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 2.6 MB/s  0:00:05
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
lst =  [(w,w.pos_,w.tag_) for w in doc]
print(lst)
# Out:
# [( , 'SPACE', '_SP'), (I, 'PRON', 'PRP'), (will, 'AUX', 'MD'), (google, 'VERB', 'VB'), (about, 'ADP', 'IN'), (facebook, 'PROPN', 'NNP')]

# %%
import spacy as sp
sp.explain('PRP')
# Out:
# 'pronoun, personal'

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
doc = nlp(' I will google about facebook')
from spacy import displacy
options={
    'distance':80,
    'compact':True,
    'color':'#fff',
    'bg':'#00a65a'
}
displacy.render(docs=doc,style='dep',jupyter=True,options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="115cb24c7a9e4e589f98c2edf275e5d6-0" class="displacy" width="530" height="217.0" direction="ltr" style="max-width: none; height: 217.0px; color: #fff; background: #00a65a; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="50"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">will</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">google</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">about</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">facebook</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-115cb24c7a9e4e589f98c2edf275e5d6-0-0" stroke-width="2px" d="M62,82.0 62,68.66666666666667 127.0,68.66666666666667 127.0,82.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-115cb24c7a9e4e589f98c2edf275e5d6-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,84.0 L58,76.0 66,76.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-115cb24c7a9e4e589f98c2edf275e5d6-0-1" stroke-width="2px" d="M142,82.0 142,55.33333333333333 290.0,55.33333333333333 290.0,82.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-115cb24c7a9e4e589f98c2edf275e5d6-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M142,84.0 L138,76.0 146,76.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-115cb24c7a9e4e589f98c2edf275e5d6-0-2" stroke-width="2px" d="M222,82.0 222,68.66666666666667 287.0,68.66666666666667 287.0,82.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-115cb24c7a9e4e589f98c2edf275e5d6-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M222,84.0 L218,76.0 226,76.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-115cb24c7a9e4e589f98c2edf275e5d6-0-3" stroke-width="2px" d="M302,82.0 302,68.66666666666667 367.0,68.66666666666667 367.0,82.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-115cb24c7a9e4e589f98c2edf275e5d6-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M367.0,84.0 L371.0,76.0 363.0,76.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-115cb24c7a9e4e589f98c2edf275e5d6-0-4" stroke-width="2px" d="M382,82.0 382,68.66666666666667 447.0,68.66666666666667 447.0,82.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-115cb24c7a9e4e589f98c2edf275e5d6-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M447.0,84.0 L451.0,76.0 443.0,76.0" fill="currentColor"/>
# </g>
# </svg></span>
