# %%
import numpy as np
import pandas as pd

import gensim
import os

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

story = []
for filename in os.listdir('data'):
    
    f = open(os.path.join('data',filename))
    corpus = f.read()
    raw_sent = sent_tokenize(corpus)
    for sent in raw_sent:
        story.append(simple_preprocess(sent))

# %%
model = gensim.models.Word2Vec(
    window=10,
    min_count=2
)

# %%
model.build_vocab(story)
model.train(story, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (6570879, 8628165)

# %%
model.wv.most_similar('daenerys')
# Out:
# [('stormborn', 0.7977370619773865),
#  ('targaryen', 0.7858642935752869),
#  ('princess', 0.7170379161834717),
#  ('queen', 0.7154407501220703),
#  ('unburnt', 0.6980820894241333),
#  ('myrcella', 0.6827728748321533),
#  ('elia', 0.678276002407074),
#  ('dorne', 0.6547552347183228),
#  ('aegon', 0.641089141368866),
#  ('consort', 0.6293439865112305)]

# %%
model.wv.

# %%
len(model.wv.index_to_key)
# Out:
# 17453

# %%
len(model.wv.get_normed_vectors()[0])
# Out:
# 100

# %%
len(y)
# Out:
# 17453

# %%
y = model.wv.index_to_key
y = model.wv.index_to_key
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
X = pca.fit_transform(model.wv.get_normed_vectors())
X
# Out:
# array([[ 0.13833064, -0.58931893,  0.00622939],
#        [ 0.16341546, -0.35266966,  0.08280425],
#        [-0.33279794, -0.533753  ,  0.21809211],
#        ...,
#        [-0.19259071,  0.09270751,  0.07340798],
#        [ 0.14805701, -0.64324534,  0.23842894],
#        [-0.1115575 , -0.36916423,  0.29211003]],
#       shape=(17453, 3), dtype=float32)

# %%
import plotly.express as px

y = model.wv.index_to_key
fig = px.scatter_3d(
    X[200:300],
    x=0,
    y=1,
    z=2,
    color=y[200:300],
    hover_name=y[200:300],
    title="Word2Vec 3D Visualization"
)

# Save as HTML file
fig.write_html("word2vec_3d_plot.html")
print("Plot saved to word2vec_3d_plot.html")
print("Open the HTML file in a browser to view the interactive 3D plot")
# Out:
# Plot saved to word2vec_3d_plot.html
# Open the HTML file in a browser to view the interactive 3D plot
