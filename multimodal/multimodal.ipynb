# %%
! pip install -q "unstructured[all-docs]" pillow pydantic lxml matplotlib

# %%
# !sudo apt-get update

# %%
# !sudo apt-get install poppler-utils

# %%
# !sudo apt-get install libleptonica-dev tesseract-ocr libtesseract-dev python3-pil tesseract-ocr-eng tesseract-ocr-script-latn

# %%
# !pip install  -q unstructured-pytesseract
# !pip install  -q tesseract-ocr

# %%
from unstructured.partition.pdf import partition_pdf

# %%
raw_pdf_elements=partition_pdf(
    filename="/content/sample-report.pdf",
    strategy="hi_res",
    extract_images_in_pdf=True,
    extract_image_block_types=["Image", "Table"],
    extract_image_block_to_payload=False,
    extract_image_block_output_dir="extracted_data"
  )
# Out:
# Warning: No languages specified, defaulting to English.
# yolox_l0.05.onnx:   0%|          | 0.00/217M [00:00<?, ?B/s]

# %%
raw_pdf_elements

# %%
Header=[]
Footer=[]
Title=[]
NarrativeText=[]
Text=[]
ListItem=[]


for element in raw_pdf_elements:
  if "unstructured.documents.elements.Header" in str(type(element)):
            Header.append(str(element))
  elif "unstructured.documents.elements.Footer" in str(type(element)):
            Footer.append(str(element))
  elif "unstructured.documents.elements.Title" in str(type(element)):
            Title.append(str(element))
  elif "unstructured.documents.elements.NarrativeText" in str(type(element)):
            NarrativeText.append(str(element))
  elif "unstructured.documents.elements.Text" in str(type(element)):
            Text.append(str(element))
  elif "unstructured.documents.elements.ListItem" in str(type(element)):
            ListItem.append(str(element))

# %%
NarrativeText

# %%
img=[]
for element in raw_pdf_elements:
  if "unstructured.documents.elements.Image" in str(type(element)):
            img.append(str(element))

# %%
raw_pdf_elements2=partition_pdf(
    filename="/content/Retrieval-Augmented-Generation-for-NLP.pdf",
    strategy="hi_res",
    extract_images_in_pdf=True,
    extract_image_block_types=["Image", "Table"],
    extract_image_block_to_payload=False,
    extract_image_block_output_dir="extracted_data2"
  )
# Out:
# Warning: No languages specified, defaulting to English.

# %%
img=[]
for element in raw_pdf_elements2:
  if "unstructured.documents.elements.Image" in str(type(element)):
            img.append(str(element))

tab=[]
for element in raw_pdf_elements2:
  if "unstructured.documents.elements.Table" in str(type(element)):
            tab.append(str(element))

NarrativeText=[]
for element in raw_pdf_elements2:
  if "unstructured.documents.elements.NarrativeText" in str(type(element)):
            NarrativeText.append(str(element))

ListItem=[]
for element in raw_pdf_elements2:
  if "unstructured.documents.elements.ListItem" in str(type(element)):
            ListItem.append(str(element))

# %%
# !pip install google-auth==2.43.0

# %%
# !pip install -q langchain_core langchain_openai langchain-google-genai

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

# %%
prompt_text = """You are an assistant tasked with summarizing tables for retrieval. \
    These summaries will be embedded and used to retrieve the raw table elements. \
    Give a concise summary of the table that is well optimized for retrieval. Table {element} """

# %%
prompt = ChatPromptTemplate.from_template(prompt_text)

# %%
import os
from google.colab import userdata
from langchain.chat_models import init_chat_model
OPENAI_API_TOKEN=userdata.get('GOOGLE_API_KEY')
os.environ["GOOGLE_API_KEY"] = OPENAI_API_TOKEN
llm = init_chat_model(
    model ='gemini-2.5-flash-tts',
    model_provider = 'google_genai'
)

# llm.invoke('hi')

# %%
summarize_chain = {"element": lambda x: x} | prompt | llm | StrOutputParser()

# %%
table_summaries=summarize_chain.batch(tab[0],{"max_concurrency": 5})
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py in _generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3039         try:
# -> 3040             response: GenerateContentResponse = self.client.models.generate_content(
#    3041                 **request,
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5214       i += 1
# -> 5215       response = self._generate_content(
#    5216           model=model, contents=contents, config=parsed_config
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    3996
# -> 3997     response = self._api_client.request(
#    3998         'post', path, request_dict, http_options
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in request(self, http_method, path, request_dict, http_options)
#    1374     )
# -> 1375     response = self._request(http_request, http_options, stream=False)
#    1376     response_body = (
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request(self, http_request, http_options, stream)
#    1208         retry = tenacity.Retrying(**retry_kwargs)
# -> 1209         return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1210
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     476         while True:
# --> 477             do = self.iter(retry_state=retry_state)
#     478             if isinstance(do, DoAttempt):
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     377         for action in self.iter_state.actions:
# --> 378             result = action(retry_state)
#     379         return result
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in <lambda>(rs)
#     399         if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 400             self._add_action_func(lambda rs: rs.outcome.result())
#     401             return
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     479                 try:
# --> 480                     result = fn(*args, **kwargs)
#     481                 except BaseException:  # noqa: B902
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request_once(self, http_request, stream)
#    1187       )
# -> 1188       errors.APIError.raise_for_response(response)
#    1189       return HttpResponse(
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_for_response(cls, response)
#     120
# --> 121     cls.raise_error(response.status_code, response_json, response)
#     122
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_error(cls, status_code, response_json, response)
#     145     if 400 <= status_code < 500:
# --> 146       raise ClientError(status_code, response_json, response)
#     147     elif 500 <= status_code < 600:
#
# ClientError: 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/gemini-2.5-flash-tts is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# /tmp/ipython-input-4126957814.py in <cell line: 0>()
# ----> 1 table_summaries=summarize_chain.batch(tab[0],{"max_concurrency": 5})
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/runnables/base.py in batch(self, inputs, config, return_exceptions, **kwargs)
#    3294             else:
#    3295                 for i, step in enumerate(self.steps):
# -> 3296                     inputs = step.batch(
#    3297                         inputs,
#    3298                         [
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/runnables/base.py in batch(self, inputs, config, return_exceptions, **kwargs)
#     911
#     912         with get_executor_for_config(configs[0]) as executor:
# --> 913             return cast("list[Output]", list(executor.map(invoke, inputs, configs)))
#     914
#     915     @overload
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result_iterator()
#     617                     # Careful not to keep a reference to the popped future
#     618                     if timeout is None:
# --> 619                         yield _result_or_cancel(fs.pop())
#     620                     else:
#     621                         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# /usr/lib/python3.12/concurrent/futures/_base.py in _result_or_cancel(***failed resolving arguments***)
#     315     try:
#     316         try:
# --> 317             return fut.result(timeout)
#     318         finally:
#     319             fut.cancel()
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     454                     raise CancelledError()
#     455                 elif self._state == FINISHED:
# --> 456                     return self.__get_result()
#     457                 else:
#     458                     raise TimeoutError()
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     399         if self._exception:
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#     403                 # Break a reference cycle with the exception in self._exception
#
# /usr/lib/python3.12/concurrent/futures/thread.py in run(self)
#      57
#      58         try:
# ---> 59             result = self.fn(*self.args, **self.kwargs)
#      60         except BaseException as exc:
#      61             self.future.set_exception(exc)
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/runnables/config.py in _wrapped_fn(*args)
#     551
#     552         def _wrapped_fn(*args: Any) -> T:
# --> 553             return contexts.pop().run(fn, *args)
#     554
#     555         return super().map(
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/runnables/base.py in invoke(input_, config)
#     904                     return e
#     905             else:
# --> 906                 return self.invoke(input_, config, **kwargs)
#     907
#     908         # If there's only one input, don't bother with the executor
#
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py in invoke(self, input, config, code_execution, stop, **kwargs)
#    2533                 raise ValueError(msg)
#    2534
# -> 2535         return super().invoke(input, config, stop=stop, **kwargs)
#    2536
#    2537     def _get_ls_params(
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     400             cast(
#     401                 "ChatGeneration",
# --> 402                 self.generate_prompt(
#     403                     [self._convert_input(input)],
#     404                     stop=stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1119     ) -> LLMResult:
#    1120         prompt_messages = [p.to_messages() for p in prompts]
# -> 1121         return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#    1122
#    1123     @override
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     929             try:
#     930                 results.append(
# --> 931                     self._generate_with_cache(
#     932                         m,
#     933                         stop=stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in _generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1223             result = generate_from_stream(iter(chunks))
#    1224         elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1225             result = self._generate(
#    1226                 messages, stop=stop, run_manager=run_manager, **kwargs
#    1227             )
#
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py in _generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3042             )
#    3043         except ClientError as e:
# -> 3044             _handle_client_error(e, request)
#    3045
#    3046         return _response_to_result(response)
#
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py in _handle_client_error(e, request)
#     143     model_name = request.get("model", "unknown")
#     144     msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 145     raise ChatGoogleGenerativeAIError(msg) from e
#     146
#     147
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-2.5-flash-tts' (NOT_FOUND): 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/gemini-2.5-flash-tts is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}
